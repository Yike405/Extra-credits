# %% [markdown]
# # Climate Change Data — Data Cleaning

# %% [markdown]
# ## 0. Import & Load Data

# %%
import pandas as pd

# .xls requires xlrd; if unavailable, convert to .xlsx first via LibreOffice
df = pd.read_excel('climate_change_edit.xls', engine='xlrd')
# if xlrd is not installed, use the converted version:
# df = pd.read_excel('climate_change_edit.xlsx', engine='openpyxl')

# %% [markdown]
# ## 1. Exploratory Data Analysis

# %%
df.shape

# %%
df.head()

# %%
df.info()

# %%
# real NaN count
df.isnull().sum()

# %%
# fake missing values encoded as '..'
(df == '..').sum()

# %% [markdown]
# ## 2. Data Cleaning

# %%
# standardize column names
df.columns = df.columns.astype(str).str.strip().str.replace(' ', '_')
print(df.columns.tolist())

# %%
# replace '..' with NaN
df = df.replace('..', pd.NA)

# %%
# drop metadata columns
df = df.drop(columns=['SCALE', 'Decimals'])

# %%
# convert year columns from object to numeric
year_cols = [str(y) for y in range(1990, 2012)]
df[year_cols] = df[year_cols].apply(pd.to_numeric)
df.dtypes

# %%
# melt wide format -> long format
df_long = df.melt(
    id_vars=['Country_code', 'Country_name', 'Series_code', 'Series_name'],
    var_name='Year',
    value_name='Value'
)

df_long['Year'] = df_long['Year'].astype(int)

# %% [markdown]
# ## 3. Validation

# %%
df_long.shape

# %%
df_long.info()

# %%
df_long.isnull().sum()

# %%
df_long.head()

# %% [markdown]
# ## 4. Save

# %%
df_long.to_csv('climate_change_cleaned.csv', index=False)
print('Saved: climate_change_cleaned.csv')
